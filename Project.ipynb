# %%
import networkx as nx
from networkx.algorithms import bipartite
import json

# %%
data = json.load(open('graph_dict.json'))

# %%
# temporary until we figure out weight
edges = []
for edge in data['edges']:
    edges.append((edge[0], edge[1]))

# %%
G = nx.Graph()
G.add_nodes_from(data['drug'], bipartite=0)
G.add_nodes_from(data['condition'], bipartite=1)
G.add_edges_from(edges)

# %%
nx.draw(G)

# %%
import csv
with open('gephi.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(edges)
